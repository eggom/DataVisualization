# %% [markdown]
# # Pandas built in Visualization

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data1=pd.read_csv('df1')

# %%
data1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
data1=pd.read_csv('df1', index_col=0)

# %%
data1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
data1['A'].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
data1['A'].hist()

# %%
plt.style.use('dark_background')

# %%
data1['A'].hist()

# %%
data1.plot.bar()

# %%
data1.plot.bar(stacked=True)

# %% [markdown]
# # Histogram Plot

# %%
plt.style.use('ggplot')

# %%
data1['A'].hist(bins=30)

# %%
data1.plot.line(x=data1.index, y='B')

# %%
data1.plot.scatter(x='A', y='B', figsize=(12,8))

# %%
data1.plot.box()

# %% [markdown]
# # KDE plot

# %%
data1.plot.kde()

# %%
data1['A'].plot.kde()

# %%
data1.plot.density()

# %%
data1.plot.scatter(x='A', y='B', figsize=(12,8), color='r', s=40)
