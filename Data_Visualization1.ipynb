# %% [markdown]
# # Simple ploting with matplotlib

# %%
import matplotlib.pyplot as plt
# this is just for jupyter notebook to show plot in here
# %matplotlib inline

# %% [markdown]
# # Creating data

# %%
import numpy as np
x=np.linspace(0,1,10)
y=x**2

# %%
x
# Out:
# array([ 0.        ,  0.11111111,  0.22222222,  0.33333333,  0.44444444,
#         0.55555556,  0.66666667,  0.77777778,  0.88888889,  1.        ])

# %%
y
# Out:
# array([ 0.        ,  0.01234568,  0.04938272,  0.11111111,  0.19753086,
#         0.30864198,  0.44444444,  0.60493827,  0.79012346,  1.        ])

# %% [markdown]
# # Simple Plot

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r') # 'r' is the color
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Simple X-Y plot')
plt.show()

# %% [markdown]
# # Creating multiple plots in the same canvas

# %%
# plt.subplot(nrows, ncols, plot_numbers)
plt.subplot(1,2,1) # left, right, width, height
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(x,y,'b*-')

# %% [markdown]
# # Object orientated method in creating plots

# %%
# create a figure object(empty canvas)
fig=plt.figure()

# add axes to figure
axes=fig.add_axes([0.0,0.0,0.8,0.9])

axes.plot(x,y,'b')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Title of the graph')
# Out:
# Text(0.5,1,'Title of the graph')

# %%
# creating blank canvas
fig=plt.figure()
axes1=fig.add_axes([0.1,0.2,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.3,0.4])

axes1.plot(x,y,'b')
axes1.set_xlabel('X axis')
axes1.set_ylabel('Y axis')
axes1.set_title('Outer plot')


axes2.plot(x,y,'r*-')
axes2.set_xlabel('X axis')
axes2.set_ylabel('Y axis')
axes2.set_title('inset plot')
# Out:
# Text(0.5,1,'inset plot')

# %% [markdown]
# # Subplots

# %%
fig, axes=plt.subplots()

axes.plot(x,y,'r*-')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title');

# %% [markdown]
# # Specifiying number of columns and rows

# %%
fig, axes=plt.subplots( nrows=1, ncols=2)

# %%
for ax in axes:
    ax.plot(x,y,'r*-')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Title')
    
fig

# %% [markdown]
# # Get rid of overlapping axes.

# %%
fig, axes=plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x,y,'b*-')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('Title')
    
fig

fig.tight_layout()

# %% [markdown]
# # Figure size, aspect ratio and DPI

# %%
fig= plt.figure(figsize=(12,16), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(6,8), dpi=100)

axes.plot(x, y, 'r*-')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# # Saving Figures

# %%
fig.savefig('xy_plot.pdf', dpi=200)

# %% [markdown]
# # legend, labels, and title

# %%
ax.set_title('Title name')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(227.8,0.5,'Y axis')

# %%
fig=plt.figure()

ax=fig.add_axes([0.5,0.2,0.8,0.8])
ax.plot(x, x**2, label='x**2')
ax.plot(x,x**3, label='x**3')
ax.legend()

# %% [markdown]
# # Speicifying legend in different location of the graph

# %%
ax.legend(loc=1) #upper right corner
#ax.legend(loc=2) #upper left corner
#ax.legend(loc=3) #lower right corner
ax.legend(loc=4) #lower left corner 

#ax.legend(loc=0) # matplotlib decide the location

fig

# %% [markdown]
# # Setting colors, line widths, line types

# %%
fig, ax=plt.subplots(figsize=(4,6), dpi=100)

ax.plot(x, x**2, 'b.-')
ax.plot(x, x**3+1, 'r*-')

# %% [markdown]
# # Color Parameter

# %%
fig, ax=plt.subplots()
ax.plot(x, x**2, color='red', alpha=0.5)# transfarant
ax.plot(x, x+2, color='#8B008B') # RGB hex code
ax.plot(x, x+3, color='#FF8C00')

# %% [markdown]
# # Line and Marker Style

# %%
fig, ax= plt.subplots(figsize=(8,6))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Graph with different style and marker')

ax.plot(x, x+1, color='red', lw=1.5)
ax.plot(x, x+2, color='red', lw=0.5)
ax.plot(x, x+3, color='red', lw=0.9)

#line style
ax.plot(x, x+4, color='blue', lw=1.5, ls='--')
ax.plot(x, x+5, color='blue', lw=1.5, ls='-.')
ax.plot(x, x+6, color='blue', lw=1.5, ls='-')



# marker symble
ax.plot(x, x+7, color='green', lw=1.5, ls='--', marker='o')
ax.plot(x, x+8, color='green', lw=1.5, ls='-.', marker='+')
ax.plot(x, x+9, color='green', lw=1.5, ls='-', marker='1')


# marker marker size
ax.plot(x, x+10, color='y', lw=1.5, ls='-', marker='o', markersize=5)
ax.plot(x, x+11, color='y', lw=1.5, ls='-', marker='o', markersize=8, markerfacecolor='red')
ax.plot(x, x+12, color='y', lw=1.5, ls='-', marker='o', markersize=10)

# %% [markdown]
# # Plot range

# %%
fig, axes=plt.subplots(1,3,figsize=(14,4))

# %%
#axes[2].plot(x, x**2+1)

# %%
fig, axes=plt.subplots(1,3,figsize=(12,4))
axes[0].plot(x, x**2 +1, x, x**3)
axes[0].set_title('Default axis')

axes[1].plot(x, x**2+1, x, x**3)
axes[1].axis('tight')
axes[1].set_title('Tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title('With custom axis');

# %% [markdown]
# # Special Ploting type

# %%
# Bar plot
plt.scatter(x,y)

# %%
# Histogram plot
from random import sample 
data=sample(range(1,1000), 100)

plt.hist(data)
# Out:
# (array([ 11.,  12.,   8.,  10.,  12.,   8.,   8.,   9.,  14.,   8.]),
#  array([   6. ,  104.7,  203.4,  302.1,  400.8,  499.5,  598.2,  696.9,
#          795.6,  894.3,  993. ]),
#  <a list of 10 Patch objects>)

# %%
data=[np.random.normal(0, std, 100) for std in range(1,4)]
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x23d5adf8b00>,
#   <matplotlib.patches.PathPatch at 0x23d5ae0d9e8>,
#   <matplotlib.patches.PathPatch at 0x23d5ae1d780>],
#  'caps': [<matplotlib.lines.Line2D at 0x23d5ae054e0>,
#   <matplotlib.lines.Line2D at 0x23d5ae05940>,
#   <matplotlib.lines.Line2D at 0x23d5ae15278>,
#   <matplotlib.lines.Line2D at 0x23d5ae156d8>,
#   <matplotlib.lines.Line2D at 0x23d5ae1dfd0>,
#   <matplotlib.lines.Line2D at 0x23d5ae26470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d5ae0d240>,
#   <matplotlib.lines.Line2D at 0x23d5ae15f98>,
#   <matplotlib.lines.Line2D at 0x23d5ae26d30>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x23d5ae05da0>,
#   <matplotlib.lines.Line2D at 0x23d5ae15b38>,
#   <matplotlib.lines.Line2D at 0x23d5ae268d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x23d5adf8dd8>,
#   <matplotlib.lines.Line2D at 0x23d5adf8f60>,
#   <matplotlib.lines.Line2D at 0x23d5ae0dc50>,
#   <matplotlib.lines.Line2D at 0x23d5ae0ddd8>,
#   <matplotlib.lines.Line2D at 0x23d5ae1d9e8>,
#   <matplotlib.lines.Line2D at 0x23d5ae1db70>]}

# %% [markdown]
# # Logarithomic Scale

# %%
fig, axes=plt.subplots(1,2, figsize=(10,4))

# %%
fig, axes=plt.subplots(1,2, figsize=(10,4))

axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].set_title('Normal Scale')
# Out:
# Text(0.5,1,'Normal Scale')

# %%
fig, axes=plt.subplots(1,2, figsize=(10,4))

axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].set_title('Normal Scale')


axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale('Log')
axes[1].set_xlabel('X')
axes[1].set_ylabel('Y')
axes[1].set_title('Logarithmic Scale "Y" ')
# Out:
# Text(0.5,1,'Logarithmic Scale "Y" ')

# %%
fig, ax= plt.subplots(figsize=(10,4))
ax.plot(x*5,(x*5)**2, x*5, (x*5)**3, lw=2)
ax.set_xticks([1,2,3,4,5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18 )

yticks=[0,50,100,150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%1f$" % y for y in yticks], fontsize=18)
# Out:
# [Text(0,0,'$0.000000$'),
#  Text(0,0,'$50.000000$'),
#  Text(0,0,'$100.000000$'),
#  Text(0,0,'$150.000000$')]

# %% [markdown]
# # Scientific Notation

# %%
fig, ax=plt.subplots(1,1)

ax.plot(x*5, (x*5)**2, x*5, np.exp(x*5))
ax.set_title('Scientific Notation')
ax.set_yticks([0,50,100,150])

from matplotlib import ticker

formatter=ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# # Axis position adjust

# %%
fig, ax= plt.subplots(1,1)

# %%
fig, ax= plt.subplots(1,1)

ax.plot(x*5, (x*5)**2, x*5, np.exp(x*5))
ax.set_yticks([0,50,100,150])

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Default title')

fig.subplots_adjust(left=0.15, right=0.9, bottom=0.1, top=0.9)

# %% [markdown]
# # Axis Grid

# %%
fig, ax=plt.subplots(1,2, figsize=(10,3))

#default grid
ax[0].plot(x*5, (x*5)**2, x*5, np.exp(x*5))
ax[0].grid(True)

ax[1].plot(x*5, (x*5)**2, x*5, np.exp(x*5))
ax[1].grid(color='b', lw=2, ls='dashed', alpha=0.5 )

# %% [markdown]
# # Twin Axis

# %%
fig, ax1=plt.subplots(figsize=(8,6))

ax1.plot(x*5+2, (x*5)**2, lw=2, color='b')
ax1.set_ylabel(r'area $(m^2)$', fontsize=18, color='b')

ax2=ax1.twinx()
ax2.plot(x*5, (x*5)**3, lw=2, color='g')
ax2.set_ylabel(r'volume $(m^3)$', fontsize=18, color='g')
# Out:
# Text(0,0.5,'volume $(m^3)$')

# %% [markdown]
# # Axes where x and y is zero

# %%
fig, ax=plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx, xx**3);

# %% [markdown]
# # different 2D plot style

# %%
n=np.array([0,1,2,3,4,5,])

fig, ax=plt.subplots(1,4,figsize=(12,3))

# %%
n=np.array([0,1,2,3,4,5,])

fig, ax=plt.subplots(1,4,figsize=(12,3))

ax[0].scatter(xx,xx+0.25*np.random.randn(len(xx)))
ax[0].set_title("scatter")

ax[1].step(n, n**2, lw=2)
ax[1].set_title('Step')

ax[2].bar(n,n**2, align='center', alpha=0.5, width=0.5)
ax[2].set_title('bar')

ax[3].fill_between(x, x**2, x**3, color='g', alpha=0.5)
ax[3].set_title('Fill Between')
# Out:
# Text(0.5,1,'Fill Between')

# %% [markdown]
# # Text Annotation

# %%
fig, ax=plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
ax.set_title('Text Annotaion')
ax.text(0.15,0.2,r'$y=x^2$', color='b', fontsize=20 )
ax.text(0.65,0.1, r'$y=x^3$', color='g', fontsize=20)
# Out:
# Text(0.65,0.1,'$y=x^3$')

# %% [markdown]
# # Multiple subplots

# %%
fig, ax=plt.subplots(2,3)
fig.tight_layout()

# %% [markdown]
# # subplot2 grids

# %%
fig=plt.figure()

ax1=plt.subplot2grid((3,3),(0,0), colspan=3)
ax2=plt.subplot2grid((3,3), (1,0), colspan=2)
ax3=plt.subplot2grid((3,3),(1,2), rowspan=2)
ax4=plt.subplot2grid((3,3),(2,0))
ax5=plt.subplot2grid((3,3),(2,1))

fig.tight_layout()

# %% [markdown]
# # 3D plot

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
Z=(2*np.pi*X**3)/2+(Y/4)**2

fig=plt.figure(figsize=(12,6))

ax=fig.add_subplot(1,2,1, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)
